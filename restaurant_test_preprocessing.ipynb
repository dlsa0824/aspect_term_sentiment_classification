# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### 把不要的欄位刪掉，改欄位名稱，改column type，把沒有label的資料刪掉

# %%
restaurant_test = pd.read_csv("dataset/restaurant_test.csv", encoding="utf-8")
#刪掉不要的欄位
restaurant_test = restaurant_test.drop(columns=['aspectTerms/aspectTerm/0/_from','aspectTerms/aspectTerm/0/_to',
                                                'aspectTerms/aspectTerm/1/_from','aspectTerms/aspectTerm/1/_to',
                                                'aspectTerms/aspectTerm/2/_from','aspectTerms/aspectTerm/2/_to',
                                                'aspectTerms/aspectTerm/3/_from','aspectTerms/aspectTerm/3/_to',
                                                'aspectTerms/aspectTerm/4/_from','aspectTerms/aspectTerm/4/_to',
                                                'aspectTerms/aspectTerm/5/_from','aspectTerms/aspectTerm/5/_to',
                                                'aspectTerms/aspectTerm/6/_from','aspectTerms/aspectTerm/6/_to',
                                                'aspectTerms/aspectTerm/7/_from','aspectTerms/aspectTerm/7/_to',
                                                'aspectTerms/aspectTerm/8/_from','aspectTerms/aspectTerm/8/_to',
                                                'aspectTerms/aspectTerm/9/_from','aspectTerms/aspectTerm/9/_to',
                                                'aspectTerms/aspectTerm/10/_from','aspectTerms/aspectTerm/10/_to',
                                                'aspectTerms/aspectTerm/11/_from','aspectTerms/aspectTerm/11/_to',
                                                'aspectTerms/aspectTerm/12/_from','aspectTerms/aspectTerm/12/_to',
                                                'aspectCategories/aspectCategory/0/_category',
                                                'aspectCategories/aspectCategory/0/_polarity',
                                                'aspectCategories/aspectCategory/1/_category',
                                                'aspectCategories/aspectCategory/1/_polarity',
                                                'aspectCategories/aspectCategory/2/_category',
                                                'aspectCategories/aspectCategory/2/_polarity',
                                                'aspectCategories/aspectCategory/3/_category',
                                                'aspectCategories/aspectCategory/3/_polarity','_id'])
#把欄位重新命名
restaurant_test = restaurant_test.rename(columns={'aspectTerms/aspectTerm/0/_term': 'aspect_0', 'aspectTerms/aspectTerm/0/_polarity': 'polarity_0',
                                                  'aspectTerms/aspectTerm/1/_term': 'aspect_1', 'aspectTerms/aspectTerm/1/_polarity': 'polarity_1',
                                                  'aspectTerms/aspectTerm/2/_term': 'aspect_2', 'aspectTerms/aspectTerm/2/_polarity': 'polarity_2',
                                                  'aspectTerms/aspectTerm/3/_term': 'aspect_3', 'aspectTerms/aspectTerm/3/_polarity': 'polarity_3',
                                                  'aspectTerms/aspectTerm/4/_term': 'aspect_4', 'aspectTerms/aspectTerm/4/_polarity': 'polarity_4',
                                                  'aspectTerms/aspectTerm/5/_term': 'aspect_5', 'aspectTerms/aspectTerm/5/_polarity': 'polarity_5',
                                                  'aspectTerms/aspectTerm/6/_term': 'aspect_6', 'aspectTerms/aspectTerm/6/_polarity': 'polarity_6',
                                                  'aspectTerms/aspectTerm/7/_term': 'aspect_7', 'aspectTerms/aspectTerm/7/_polarity': 'polarity_7',
                                                  'aspectTerms/aspectTerm/8/_term': 'aspect_8', 'aspectTerms/aspectTerm/8/_polarity': 'polarity_8',
                                                  'aspectTerms/aspectTerm/9/_term': 'aspect_9', 'aspectTerms/aspectTerm/9/_polarity': 'polarity_9',
                                                  'aspectTerms/aspectTerm/10/_term': 'aspect_10', 'aspectTerms/aspectTerm/10/_polarity': 'polarity_10',
                                                  'aspectTerms/aspectTerm/11/_term': 'aspect_11', 'aspectTerms/aspectTerm/11/_polarity': 'polarity_11',
                                                  'aspectTerms/aspectTerm/12/_term': 'aspect_12', 'aspectTerms/aspectTerm/12/_polarity': 'polarity_12'})
# 把欄位型態改成str
restaurant_test['aspect_0'] = restaurant_test['aspect_0'].astype(str)
restaurant_test['aspect_1'] = restaurant_test['aspect_1'].astype(str)
restaurant_test['aspect_2'] = restaurant_test['aspect_2'].astype(str)
restaurant_test['aspect_3'] = restaurant_test['aspect_3'].astype(str)
restaurant_test['aspect_4'] = restaurant_test['aspect_4'].astype(str)
restaurant_test['aspect_5'] = restaurant_test['aspect_5'].astype(str)
restaurant_test['aspect_6'] = restaurant_test['aspect_6'].astype(str)
restaurant_test['aspect_7'] = restaurant_test['aspect_7'].astype(str)
restaurant_test['aspect_8'] = restaurant_test['aspect_8'].astype(str)
restaurant_test['aspect_9'] = restaurant_test['aspect_9'].astype(str)
restaurant_test['aspect_10'] = restaurant_test['aspect_10'].astype(str)
restaurant_test['aspect_11'] = restaurant_test['aspect_11'].astype(str)
restaurant_test['aspect_12'] = restaurant_test['aspect_12'].astype(str)

restaurant_test['polarity_0'] = restaurant_test['polarity_0'].astype(str)
restaurant_test['polarity_1'] = restaurant_test['polarity_1'].astype(str)
restaurant_test['polarity_2'] = restaurant_test['polarity_2'].astype(str)
restaurant_test['polarity_3'] = restaurant_test['polarity_3'].astype(str)
restaurant_test['polarity_4'] = restaurant_test['polarity_4'].astype(str)
restaurant_test['polarity_5'] = restaurant_test['polarity_5'].astype(str)
restaurant_test['polarity_6'] = restaurant_test['polarity_6'].astype(str)
restaurant_test['polarity_7'] = restaurant_test['polarity_7'].astype(str)
restaurant_test['polarity_8'] = restaurant_test['polarity_8'].astype(str)
restaurant_test['polarity_9'] = restaurant_test['polarity_9'].astype(str)
restaurant_test['polarity_10'] = restaurant_test['polarity_10'].astype(str)
restaurant_test['polarity_11'] = restaurant_test['polarity_11'].astype(str)
restaurant_test['polarity_12'] = restaurant_test['polarity_12'].astype(str)

restaurant_test=restaurant_test.drop(restaurant_test[restaurant_test['aspect_0']=='nan'].index) #把沒有Label的資料刪掉
restaurant_test = restaurant_test.reset_index(drop=True)
print('有label的筆數:',len(restaurant_test))
restaurant_test.head()
# Out:
# 有label的筆數: 606
#                                                 text        aspect_0  \
# 0                    The bread is top notch as well.           bread
# 1  I have to say they have one of the fastest del...  delivery times
# 2        Food is always fresh and hot- ready to eat!            Food
# 3      Did I mention that the coffee is OUTSTANDING?          coffee
# 4  Certainly not the best sushi in New York, howe...           sushi
#
#   polarity_0 aspect_1 polarity_1 aspect_2 polarity_2 aspect_3 polarity_3  \
# 0   positive      nan        nan      nan        nan      nan        nan
# 1   positive      nan        nan      nan        nan      nan        nan
# 2   positive      nan        nan      nan        nan      nan        nan
# 3   positive      nan        nan      nan        nan      nan        nan
# 4   conflict    place   positive      nan        nan      nan        nan
#
#   aspect_4  ... aspect_8 polarity_8 aspect_9 polarity_9 aspect_10 polarity_10  \
# ...

# %% [markdown]
# ### 看每筆資料的apsect數各有多少筆資料

# %%
restaurant_copy = restaurant_test
aspect_13 = restaurant_copy[restaurant_copy['aspect_12'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_12'] != 'nan'].index)

aspect_12 = restaurant_copy[restaurant_copy['aspect_11'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_11'] != 'nan'].index)

aspect_11 = restaurant_copy[restaurant_copy['aspect_10'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_10'] != 'nan'].index)

aspect_10 = restaurant_copy[restaurant_copy['aspect_9'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_9'] != 'nan'].index)

aspect_9 = restaurant_copy[restaurant_copy['aspect_8'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_8'] != 'nan'].index)

aspect_8 = restaurant_copy[restaurant_copy['aspect_7'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_7'] != 'nan'].index)

aspect_7 = restaurant_copy[restaurant_copy['aspect_6'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_6'] != 'nan'].index)

aspect_6 = restaurant_copy[restaurant_copy['aspect_5'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_5'] != 'nan'].index)

aspect_5 = restaurant_copy[restaurant_copy['aspect_4'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_4'] != 'nan'].index)

aspect_4 = restaurant_copy[restaurant_copy['aspect_3'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_3'] != 'nan'].index)

aspect_3 = restaurant_copy[restaurant_copy['aspect_2'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_2'] != 'nan'].index)

aspect_2 = restaurant_copy[restaurant_copy['aspect_1'] != 'nan']
restaurant_copy = restaurant_copy.drop(restaurant_copy[restaurant_copy['aspect_1'] != 'nan'].index)

aspect_1 = restaurant_copy

print('所有資料數:',len(restaurant_test))
print('1個aspect的資料數:',len(aspect_1))
print('2個aspect的資料數:',len(aspect_2))
print('3個aspect的資料數:',len(aspect_3))
print('4個aspect的資料數:',len(aspect_4))
print('5個aspect的資料數:',len(aspect_5))
print('6個aspect的資料數:',len(aspect_6))
print('7個aspect的資料數:',len(aspect_7))
print('8個aspect的資料數:',len(aspect_8))
print('9個aspect的資料數:',len(aspect_9))
print('10個aspect的資料數:',len(aspect_10))
print('11個aspect的資料數:',len(aspect_11))
print('12個aspect的資料數:',len(aspect_12))
print('13個aspect的資料數:',len(aspect_13))
# Out:
# 所有資料數: 606
# 1個aspect的資料數: 290
# 2個aspect的資料數: 186
# 3個aspect的資料數: 80
# 4個aspect的資料數: 31
# 5個aspect的資料數: 14
# 6個aspect的資料數: 3
# 7個aspect的資料數: 1
# 8個aspect的資料數: 0
# 9個aspect的資料數: 0
# 10個aspect的資料數: 0
# 11個aspect的資料數: 0
# 12個aspect的資料數: 0
# 13個aspect的資料數: 1

# %% [markdown]
# ### 把每筆資料對每個aspect切開，讓一筆資料只能有一個aspect，如果一筆資料有多個aspect，重複text形成一對多的格式

# %%
# 創一個空的dataframe
restaurant_test_1 = pd.DataFrame(columns=['text','aspect','polarity'])

# 把每筆資料的text 對 aspect terms 分開成 一個text對一個aspect、polarity
for i in tqdm(range(len(restaurant_test))):
    count = 0
    target_a = restaurant_test.loc[i,'aspect_0'] # aspect_0值
    target_p = restaurant_test.loc[i,'polarity_0'] # polarity_0的值
    while((count<=12) and (target_a != 'nan')): #如果count<=12 (因為dataframe只有0-12個aspect) 且 目標aspect值不是'nan'
        pd_temp = pd.DataFrame([[restaurant_test.loc[i,'text'], target_a, target_p]],
                              columns=['text','aspect','polarity']) # 將text、aspect、polarity變成dataframe格式
        restaurant_test_1 = restaurant_test_1.append(pd_temp, ignore_index=True) # 將dataframe加在下面
        count += 1
        if count>12: # 判斷aspect數是否有超過資料集裡的aspect數，如果超過就break
            break
        a = 'aspect_'+ str(count) #目標放在下一個aspect column name
        p = 'polarity_'+str(count) # 下一個 polarity column name
        target_a = restaurant_test.loc[i,a] # 下一個aspect 值
        target_p = restaurant_test.loc[i,p] # 下一個polarity 值
    restaurant_test.loc[i,'aspect count'] = str(count)
restaurant_test_1
# Out:
# 100%|██████████| 606/606 [00:01<00:00, 483.66it/s]
#                                                    text  \
# 0                       The bread is top notch as well.
# 1     I have to say they have one of the fastest del...
# 2           Food is always fresh and hot- ready to eat!
# 3         Did I mention that the coffee is OUTSTANDING?
# 4     Certainly not the best sushi in New York, howe...
# ...                                                 ...
# 1129  Creamy appetizers--taramasalata, eggplant sala...
# 1130  Creamy appetizers--taramasalata, eggplant sala...
# 1131  Creamy appetizers--taramasalata, eggplant sala...
# 1132  Creamy appetizers--taramasalata, eggplant sala...
# 1133  Creamy appetizers--taramasalata, eggplant sala...
#
#                                                aspect  polarity
# 0                                               bread  positive
# 1                                      delivery times  positive
# ...

# %%
# 看分開aspect term資料筆數有沒有一樣多
print('切成單一資料筆數:',len(restaurant_test_1))
print('每個aspect相加:',len(aspect_1)+len(aspect_2)*2+len(aspect_3)*3+len(aspect_4)*4+len(aspect_5)*5+
      len(aspect_6)*6+len(aspect_7)*7+len(aspect_13)*13)
# Out:
# 切成單一資料筆數: 1134
# 每個aspect相加: 1134

# %%
# 把polarity是conflict的資料刪除，(因為conflict資料量太少)
restaurant_test_1=restaurant_test_1.drop(restaurant_test_1[restaurant_test_1['polarity']=='conflict'].index)
print('扣掉label為conflict的資料數:',len(restaurant_test_1))
restaurant_test_1
# Out:
# 扣掉label為conflict的資料數: 1120
#                                                    text  \
# 0                       The bread is top notch as well.
# 1     I have to say they have one of the fastest del...
# 2           Food is always fresh and hot- ready to eat!
# 3         Did I mention that the coffee is OUTSTANDING?
# 5     Certainly not the best sushi in New York, howe...
# ...                                                 ...
# 1129  Creamy appetizers--taramasalata, eggplant sala...
# 1130  Creamy appetizers--taramasalata, eggplant sala...
# 1131  Creamy appetizers--taramasalata, eggplant sala...
# 1132  Creamy appetizers--taramasalata, eggplant sala...
# 1133  Creamy appetizers--taramasalata, eggplant sala...
#
#                                                aspect  polarity
# 0                                               bread  positive
# 1                                      delivery times  positive
# 2                                                Food  positive
# ...

# %%
restaurant_test_1 = restaurant_test_1.reset_index(drop=True)
restaurant_test_1.to_csv('restaurant_test_processed.csv',index=0)
